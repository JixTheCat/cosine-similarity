# %% [markdown]
# # Simple algorithms
#
# Many algorithms used can help determine whether a word is similar to another, which is used in applications such as spell checking. The first algorithm we can look at is Cosine Similarity. It is a simple function that determines the similarity of one string of letters to another and is computed by:
#
# $$\frac{\sum_{i=1}^{n}A_i B_i}{\sqrt{\sum_{i=1}^{n}A_i^2}\sqrt{\sum_{i=1}^{n}B_i^2}}$$
#
# This return a percentage of how similar the two vectors, or in this case, words are:

# %%
from math import sqrt

def letters_to_numbers(letters):
    """Convert a string of letters to numbers (Not case sensitive)."""
    numbers = []
    for letter in letters.lower():
        numbers.append(ord(letter))
    return numbers

def cosine_similarity(a, b):
    """Returns the cosine similarity of two vectors a and b."""
    a = letters_to_numbers(a)
    b = letters_to_numbers(b)
    a2 = [x**2 for x in a]
    b2 = [x**2 for x in b]

    ab =  [x * y for (x, y) in zip(a,b)]

    return sum(ab)/sqrt(sum(a2)*sum(b2))

# %% [markdown]
# We can see an example of this using the two phrases: "HallO Worlds" and "hello world":

# %%
cosine_similarity("HallO Worlds", "hello world")
# Out:
# 0.9482289714614682

# %% [markdown]
# This shows that they are approximately 94.8% similar.
#
# This type of technique is used to search for likely spelling mistakes and their best solutions, and even to compare articles to see how similar they are. The algorithm can be altered to include words instead of letters for larger readings.
#
# To help tackle problems that have multiple words we can turn to tokenization. THis process also involves the use of pairing to identify that a word can be a noun, verb etc. below is a continuation of the above example:

# %%
from nltk.tokenize import word_tokenize

phrase_one = "HallO Worlds"
phrase_two =  "hello world"

print("phrase one: {}".format(word_tokenize(phrase_one)))
print("phrase two: {}\n".format(word_tokenize(phrase_two)))
for i in range(2):
    print("{}:{} = {}".format(
        word_tokenize(phrase_one)[i]
        , word_tokenize(phrase_two)[i]
        , cosine_similarity(word_tokenize(phrase_one)[i], word_tokenize(phrase_two)[i])
    ))
# Out:
# phrase one: ['HallO', 'Worlds']
# phrase two: ['hello', 'world']
#
# HallO:hello = 0.999882588914304
# Worlds:world = 0.9067335581962246

# %% [markdown]
# We can combine this to look at possible keywords of a document by using tokenization and matching words that are similar then listing them simply by frequency:

# %%
words
# Out:
# ['ar',
#  'x',
#  'iv',
#  ':2',
#  '20',
#  '5',
#  '.',
#  '08',
#  '62',
#  '3v',
#  '1',
#  '[',
#  'm',
#  'at',
#  'h.',
#  'a',
#  'g',
#  ']',
#  '1',
#  '7',
#  'm',
#  'ay',
#  '2',
#  '02',
#  '2',
#  'artin',
#  'algebraization',
#  'for',
#  'pairs',
#  'with',
#  'applications',
#  'to',
#  'the',
#  'local',
#  'structure',
#  'of',
#  'stacks',
#  'and',
#  'ferrand',
#  'pushouts',
#  'jarod',
#  'alper',
#  ',',
#  'daniel',
#  'halpern-leistner',
#  ',',
#  'jack',
#  'hall',
#  ',',
#  'and',
#  'david',
#  'rydh',
#  'abstract',
#  '.',
#  'we',
#  'give',
#  'a',
#  'variant',
#  'of',
#  'artin',
#  'algebraization',
#  'along',
#  'closed',
#  'subschemes',
#  'and',
#  'closed',
#  'substacks',
#  '.',
#  'our',
#  'main',
#  'application',
#  'is',
#  'the',
#  'existence',
#  'of',
#  'étale',
#  ',',
#  'smooth',
#  ',',
#  'or',
#  'syntomic',
#  'neighborhoods',
#  'of',
#  'closed',
#  'subschemes',
#  'and',
#  'closed',
#  'substacks',
#  '.',
#  'in',
#  'par-',
#  'ticular',
#  ',',
#  'we',
#  'prove',
#  'local',
#  'structure',
#  'theorems',
#  'for',
#  'stacks',
#  'and',
#  'their',
#  'derived',
#  'coun-',
#  'terparts',
#  'and',
#  'the',
#  'existence',
#  'of',
#  'henselizations',
#  'along',
#  'linearly',
#  'fundamental',
#  'closed',
#  'substacks',
#  '.',
#  'these',
#  'results',
#  'establish',
#  'the',
#  'existence',
#  'of',
#  'ferrand',
#  'pushouts',
#  ',',
#  'which',
#  'answers',
#  'positively',
#  'a',
#  'question',
#  'of',
#  'temkin–tyomkin',
#  '.',
#  '1',
#  '.',
#  'introduction',
#  'the',
#  'main',
#  'technical',
#  'result',
#  'of',
#  'this',
#  'paper',
#  'is',
#  'a',
#  'generalization',
#  'of',
#  'artin',
#  '’',
#  's',
#  'algebraiza-',
#  'tion',
#  'theorem',
#  '[',
#  'art69',
#  ',',
#  'thm',
#  '.',
#  '1.6',
#  ']',
#  ':',
#  'from',
#  'algebraizations',
#  'of',
#  'complete',
#  'local',
#  'rings',
#  'to',
#  'algebraizations',
#  'of',
#  'rings',
#  'complete',
#  'along',
#  'an',
#  'ideal',
#  '.',
#  'it',
#  'is',
#  'proven',
#  'using',
#  'artin',
#  'approxi-',
#  'mation',
#  'over',
#  'henselian',
#  'pairs',
#  'following',
#  'the',
#  'approach',
#  'of',
#  '[',
#  'cj02',
#  ']',
#  'and',
#  '[',
#  'ahr20',
#  ',',
#  'app',
#  '.',
#  'a',
#  ']',
#  '.',
#  'theorem',
#  '1.1',
#  '(',
#  'artin',
#  'algebraization',
#  'for',
#  'pairs',
#  ')',
#  '.',
#  'let',
#  's',
#  'be',
#  'an',
#  'excellent',
#  'affine',
#  'scheme',
#  'and',
#  'let',
#  'x',
#  'be',
#  'a',
#  'category',
#  'fibered',
#  'in',
#  'groupoids',
#  ',',
#  'locally',
#  'of',
#  'finite',
#  'presentation',
#  'over',
#  's.',
#  'let',
#  'z',
#  'be',
#  'an',
#  'affine',
#  'scheme',
#  'over',
#  's',
#  ',',
#  'complete',
#  'along',
#  'a',
#  'closed',
#  'subscheme',
#  'z0',
#  '.',
#  'assume',
#  'that',
#  'z0',
#  '→',
#  's',
#  'is',
#  'of',
#  'finite',
#  'type',
#  '.',
#  'let',
#  'η',
#  ':',
#  'z',
#  '→x',
#  'be',
#  'a',
#  'morphism',
#  ',',
#  'formally',
#  'versal',
#  'at',
#  'z0',
#  '.',
#  'then',
#  'there',
#  'exist',
#  '(',
#  '1',
#  ')',
#  'an',
#  'affine',
#  'scheme',
#  'w',
#  'of',
#  'finite',
#  'type',
#  'over',
#  's',
#  ',',
#  '(',
#  '2',
#  ')',
#  'a',
#  'closed',
#  'subscheme',
#  'w0',
#  '→֒w',
#  ',',
#  '(',
#  '3',
#  ')',
#  'a',
#  'morphism',
#  'ξ',
#  ':',
#  'w',
#  '→x',
#  'over',
#  's',
#  'and',
#  '(',
#  '4',
#  ')',
#  'a',
#  'morphism',
#  'ϕ',
#  ':',
#  '(',
#  'z',
#  ',',
#  'z0',
#  ')',
#  '→',
#  '(',
#  'w',
#  ',',
#  'w0',
#  ')',
#  'over',
#  's',
#  'such',
#  'that',
#  'the',
#  'induced',
#  'morphism',
#  'ϕ̂',
#  ':',
#  'z',
#  '→',
#  'ŵ',
#  'is',
#  'an',
#  'isomorphism',
#  'and',
#  'the',
#  'isomorphism',
#  'ϕn',
#  ':',
#  'zn',
#  '→wn',
#  'on',
#  'infinitesimal',
#  'neighborhoods',
#  'is',
#  'compatible',
#  'with',
#  'η',
#  'and',
#  'ξ',
#  'for',
#  'every',
#  'n.',
#  'we',
#  'prove',
#  'a',
#  'more',
#  'general',
#  'version',
#  'when',
#  'z',
#  'is',
#  'a',
#  'stack',
#  'in',
#  'theorem',
#  '2.3',
#  '.',
#  'this',
#  'gener-',
#  'alizes',
#  '[',
#  'ahr20',
#  ',',
#  'app',
#  '.',
#  'a',
#  ']',
#  'and',
#  'is',
#  'used',
#  'to',
#  'establish',
#  'a',
#  'local',
#  'structure',
#  'theorem',
#  'for',
#  'stacks',
#  '(',
#  'theorem',
#  '1.3',
#  ')',
#  '.',
#  'we',
#  'will',
#  'return',
#  'to',
#  'this',
#  'shortly',
#  '.',
#  'application',
#  ':',
#  'étale',
#  'neighborhoods',
#  'of',
#  'affine',
#  'subschemes',
#  '.',
#  'as',
#  'an',
#  'application',
#  'of',
#  'theorem',
#  '1.1',
#  'we',
#  'have',
#  'the',
#  'existence',
#  'of',
#  'affine',
#  'étale',
#  'neighborhoods',
#  '.',
#  'date',
#  ':',
#  'may',
#  '17',
#  ',',
#  '2022',
#  '.',
#  '2020',
#  'mathematics',
#  'subject',
#  'classification',
#  '.',
#  '14b12',
#  ',',
#  '14d23',
#  ',',
#  '13b12',
#  '.',
#  'key',
#  'words',
#  'and',
#  'phrases',
#  '.',
#  'artin',
#  'algebraization',
#  ',',
#  'local',
#  'structure',
#  'of',
#  'stacks',
#  ',',
#  'milnor',
#  'squares',
#  ',',
#  'ferrand',
#  'pushouts',
#  ',',
#  'derived',
#  'stacks',
#  ',',
#  'henselization',
#  '.',
#  'the',
#  'first',
#  'author',
#  'was',
#  'partially',
#  'supported',
#  'by',
#  'nsf',
#  'grant',
#  'dms-1801976',
#  'and',
#  'dms-2100088',
#  '.',
#  'the',
#  'second',
#  'author',
#  'was',
#  'partially',
#  'supported',
#  'by',
#  'nsf',
#  'grants',
#  'dms-1945478',
#  '(',
#  'career',
#  ')',
#  ',',
#  'dms-1601967',
#  ',',
#  'a',
#  'simons',
#  'collaboration',
#  'grant',
#  'and',
#  'the',
#  'alfred',
#  'p.',
#  'sloan',
#  'foundation',
#  '.',
#  'the',
#  'third',
#  'author',
#  'was',
#  'partially',
#  'supported',
#  'by',
#  'the',
#  'australian',
#  'research',
#  'council',
#  'dp210103397',
#  '.',
#  'the',
#  'fourth',
#  'author',
#  'was',
#  'supported',
#  'by',
#  'the',
#  'swedish',
#  'research',
#  'council',
#  '2015-05554',
#  'and',
#  'the',
#  'göran',
#  'gustafsson',
#  'foundation',
#  'for',
#  'research',
#  'in',
#  'natural',
#  'sciences',
#  'and',
#  'medicine',
#  '.',
#  '1',
#  'http',
#  ':',
#  '//arxiv.org/abs/2205.08623v1',
#  '2',
#  'j.',
#  'alper',
#  ',',
#  'd.',
#  'halpern-leistner',
#  ',',
#  'j',
#  '.',
#  'hall',
#  ',',
#  'and',
#  'd.',
#  'rydh',
#  'theorem',
#  '1.2',
#  '(',
#  'affine',
#  'étale',
#  'neighborhoods',
#  ')',
#  '.',
#  'let',
#  'x',
#  'be',
#  'a',
#  'quasi-separated',
#  'algebraic',
#  'stack',
#  'with',
#  'affine',
#  'stabilizers',
#  ',',
#  'and',
#  'consider',
#  'a',
#  'diagram',
#  'w0',
#  '�',
#  '�',
#  '//❴❴❴',
#  'f0',
#  '��',
#  'w',
#  'f',
#  '��',
#  '✤',
#  '✤',
#  '✤',
#  'x0',
#  '�',
#  '�',
#  '//',
#  'x',
#  ',',
#  'where',
#  'x0',
#  '→֒x',
#  'is',
#  'a',
#  'closed',
#  'immersion',
#  'and',
#  'f0',
#  ':',
#  'w0',
#  '→x0',
#  'is',
#  'an',
#  'étale',
#  '(',
#  'resp',
#  '.',
#  'smooth',
#  ')',
#  'morphism',
#  'with',
#  'w0',
#  'affine',
#  '.',
#  'then',
#  'there',
#  'exist',
#  'an',
#  'affine',
#  'scheme',
#  'w',
#  'and',
#  'an',
#  'étale',
#  '(',
#  'resp',
#  '.',
#  'smooth',
#  ')',
#  'morphism',
#  'f',
#  ':',
#  'w',
#  '→x',
#  'such',
#  'that',
#  'f',
#  '|x0',
#  '=',
#  'f0',
#  '.',
#  'if',
#  'x',
#  'is',
#  'an',
#  'affine',
#  'scheme',
#  ',',
#  'then',
#  'theorem',
#  '1.2',
#  'is',
#  '[',
#  'sp',
#  ',',
#  '04d1',
#  ']',
#  '(',
#  'f0',
#  'étale',
#  ')',
#  'and',
#  '[',
#  'elk73',
#  ',',
#  'thm',
#  '.',
#  '6',
#  ']',
#  '(',
#  'f0',
#  'smooth',
#  ')',
#  '.',
#  'for',
#  'non-affine',
#  'schemes',
#  'and',
#  'algebraic',
#  'spaces',
#  ',',
#  'these',
#  'results',
#  'are',
#  'new',
#  'and',
#  'answer',
#  'positively',
#  'a',
#  'question',
#  'of',
#  'temkin',
#  'and',
#  'tyomkin',
#  '[',
#  'tt16',
#  ',',
#  'qstn',
#  '.',
#  '5.3',
#  ']',
#  '.',
#  'application',
#  ':',
#  'local',
#  'structure',
#  'of',
#  'stacks',
#  '.',
#  'we',
#  'now',
#  'generalize',
#  'theorem',
#  '1.2',
#  'from',
#  'extending',
#  'affine',
#  'étale',
#  'neighborhoods',
#  'to',
#  'extending',
#  'linearly',
#  'fundamental',
#  'étale',
#  'neigh-',
#  'borhoods',
#  '.',
#  'by',
#  'definition',
#  ',',
#  'an',
#  'algebraic',
#  'stack',
#  'x',
#  'is',
#  'fundamental',
#  'if',
#  'there',
#  'is',
#  'an',
#  'affine',
#  'morphism',
#  'x',
#  '→',
#  'bgln',
#  ',',
#  'z',
#  'for',
#  'some',
#  'n',
#  ',',
#  'and',
#  'linearly',
#  'fundamental',
#  'if',
#  'it',
#  'is',
#  'fundamental',
#  'and',
#  'cohomologically',
#  'affine',
#  ';',
#  'see',
#  '[',
#  'ahr19',
#  ',',
#  '§2.2',
#  ']',
#  'for',
#  'further',
#  'discussion',
#  '.',
#  'in',
#  'order',
#  'to',
#  'formulate',
#  'mixed-characteristic',
#  'versions',
#  'of',
#  'the',
#  'local',
#  'structure',
#  'results',
#  ',',
#  'we',
#  'recall',
#  'from',
#  '[',
#  'ahr19',
#  ',',
#  '§15',
#  ']',
#  'the',
#  'following',
#  'conditions',
#  'on',
#  'an',
#  'algebraic',
#  'stack',
#  'x',
#  '.',
#  '(',
#  'fc',
#  ')',
#  'there',
#  'is',
#  'only',
#  'a',
#  'finite',
#  'number',
#  'of',
#  'different',
#  'characteristics',
#  'in',
#  'x',
#  '.',
#  '(',
#  'pc',
#  ')',
#  'every',
#  'closed',
#  'point',
#  'of',
#  'x',
#  'has',
#  'positive',
#  'characteristic',
#  '.',
#  '(',
#  'n',
#  ')',
#  'every',
#  'closed',
#  'point',
#  'of',
#  'x',
#  'has',
#  'nice',
#  'stabilizer',
#  '[',
#  'hr15',
#  ',',
#  'defn',
#  '.',
#  '1.1',
#  ']',
#  '(',
#  'i.e.',
#  ',',
#  'is',
#  'an',
#  'extension',
#  'of',
#  'a',
#  'finite',
#  'linearly',
#  'reductive',
#  'group',
#  'scheme',
#  'by',
#  'an',
#  'algebraic',
#  'group',
#  'of',
#  'multiplicative',
#  'type',
#  ')',
#  '.',
#  'if',
#  'x',
#  'is',
#  'linearly',
#  'fundamental',
#  ',',
#  'then',
#  '(',
#  'pc',
#  ')',
#  '=⇒',
#  '(',
#  'n',
#  ')',
#  'as',
#  'linearly',
#  'reductive',
#  'group',
#  'schemes',
#  'in',
#  'positive',
#  'characteristic',
#  'are',
#  'nice',
#  '[',
#  'nag62',
#  ']',
#  ',',
#  '[',
#  'hr15',
#  ',',
#  'thm',
#  '.',
#  '1.2',
#  ']',
#  '.',
#  'the',
#  'condition',
#  'that',
#  'we',
#  'often',
#  'impose',
#  'will',
#  'be',
#  'of',
#  'the',
#  'following',
#  'form',
#  'for',
#  'some',
#  'morphism',
#  'of',
#  'stacks',
#  'w0',
#  '→',
#  'x',
#  ':',
#  'assume',
#  'either',
#  'that',
#  'w0',
#  'satisfies',
#  '(',
#  'n',
#  ')',
#  ',',
#  'or',
#  'x',
#  'satisfies',
#  '(',
#  'fc',
#  ')',
#  '.',
#  'we',
#  'also',
#  'remind',
#  'the',
#  'reader',
#  'of',
#  'another',
#  'type',
#  'of',
#  'algebraic',
#  'stack',
#  'from',
#  '[',
#  'ahr19',
#  ',',
#  '§2.2',
#  ']',
#  ':',
#  'an',
#  'algebraic',
#  'stack',
#  'x',
#  'is',
#  'nicely',
#  'fundamental',
#  'if',
#  'it',
#  'admits',
#  'an',
#  'affine',
#  'morphism',
#  'to',
#  'bsq',
#  ',',
#  'where',
#  'q→',
#  ...]

# %%
# we read in a pdf file:
from tika import parser

raw = parser.from_file('2205.08623.pdf')
#print(raw['content'])

words = [word.lower() for word in word_tokenize(raw['content'])]

word_counts = {}

for word in words:
    word_counts[word] = words.count(word)

word_counts = {word: count for word, count in sorted(word_counts.items(), key=lambda word: word[1], reverse=True)}
    
for word in word_counts.keys():
    if len(word) > 3:
        print("{}: {}".format(word, word_counts[word]))
# Out:
# that: 253
# affine: 143
# theorem: 125
# algebraic: 110
# then: 106
# closed: 103
# with: 99
# fundamental: 96
# morphism: 89
# stacks: 79
# smooth: 69
# étale: 64
# such: 63
# finite: 62
# linearly: 60
# there: 60
# this: 58
# over: 57
# immersion: 57
# since: 52
# local: 45
# stack: 42
# assume: 41
# where: 41
# structure: 40
# isomorphism: 39
# proof: 39
# resp: 38
# neighborhood: 37
# open: 36
# quasi-compact: 34
# pairs: 33
# derived: 33
# have: 32
# follows: 32
# case: 32
# type: 31
# ahr19: 31
# scheme: 30
# every: 30
# lemma: 28
# algebraization: 27
# along: 27
# from: 27
# quasi-separated: 27
# space: 27
# artin: 26
# following: 26
# presentation: 26
# point: 26
# satisfies: 26
# syntomic: 25
# exists: 25
# prop: 24
# after: 24
# hall: 23
# rydh: 23
# complete: 23
# also: 23
# substack: 23
# neighborhoods: 22
# prove: 22
# locally: 22
# flat: 22
# diagonal: 22
# pair: 22
# which: 21
# application: 20
# result: 19
# induced: 19
# schemes: 19
# property: 19
# thus: 19
# surjective: 19
# morphisms: 19
# existence: 18
# diagram: 18
# moduli: 18
# geometric: 18
# section: 18
# noetherian: 18
# alper: 17
# group: 17
# pushout: 17
# spec: 17
# image: 17
# math: 17
# halpern-leistner: 16
# spaces: 16
# nisnevich: 16
# apply: 16
# pushouts: 15
# some: 15
# separated: 15
# square: 15
# compatible: 14
# stabilizers: 14
# replacing: 14
# replace: 14
# step: 14
# ahr20: 13
# points: 13
# note: 13
# large: 13
# proposition: 13
# sequence: 13
# hence: 13
# results: 12
# first: 12
# http: 12
# characteristic: 12
# stabilizer: 12
# representable: 12
# arrange: 12
# category: 11
# definition: 11
# bgln: 11
# further: 11
# only: 11
# reductive: 11
# resolution: 11
# sufficiently: 11
# zariskification: 11
# because: 11
# ryd15: 11
# bundle: 11
# ferrand: 10
# david: 10
# these: 10
# versal: 10
# when: 10
# conditions: 10
# positive: 10
# good: 10
# 2-commutative: 10
# limit: 10
# indeed: 10
# base: 10
# claim: 10
# jack: 9
# subscheme: 9
# formally: 9
# will: 9
# consider: 9
# nice: 9
# phism: 9
# quasi-: 9
# both: 9
# maps: 9
# compact: 9
# denote: 9
# finitely: 9
# obtain: 9
# specz: 9
# give: 8
# exist: 8
# general: 8
# version: 8
# mathematics: 8
# cohomologically: 8
# either: 8
# nicely: 8
# admits: 8
# does: 8
# covering: 8
# modules: 8
# generated: 8
# classical: 8
# immersions: 8
# remains: 8
# through: 8
# main: 7
# using: 7
# groups: 7
# example: 7
# residual: 7
# gerbe: 7
# fer03: 7
# unique: 7
# dqcoh: 7
# established: 7
# quasi-smooth: 7
# defined: 7
# duality: 7
# cohomological: 7
# dimension: 7
# criterion: 7
# containing: 7
# specb: 7
# monomorphism: 7
# factorization: 7
# henselizations: 6
# question: 6
# rings: 6
# ideal: 6
# henselization: 6
# extension: 6
# condition: 6
# mor-: 6
# zero: 6
# inverse: 6
# remark: 6
# quasi-affine: 6
# generation: 6
# hr17: 6
# identity: 6
# 1-stack: 6
# adic: 6
# particular: 6
# tannaka: 6
# graded: 6
# surjection: 6
# approximation: 6
# construction: 6
# change: 6
# write: 6
# isomorphisms: 6
# vector: 6
# hal17: 6
# 2-cartesian: 6
# show: 6
# tt17: 6
# pro-open: 6
# ray68: 6
# bglr: 6
# algebra: 6
# jarod: 5
# subschemes: 5
# substacks: 5
# theorems: 5
# henselian: 5
# excellent: 5
# second: 5
# recall: 5
# i.e.: 5
# non-noetherian: 5
# pro-affine-immersions: 5
# 2-category: 5
# inclusion: 5
# generalizes: 5
# implies: 5
# quotient: 5
# sheaves: 5
# compactly: 5
# hnr19: 5
# component: 5
# categories: 5
# given: 5
# commutative: 5
# same: 5
# gives: 5
# coherently: 5
# coherent: 5
# completion: 5
# 2.10: 5
# finally: 5
# lifting: 5
# enough: 5
# contains: 5
# factor: 5
# suffices: 5
# isomorphic: 5
# standard: 5
# methods: 5
# extend: 5
# resulting: 5
# ryd16: 5
# intersection: 5
# extends: 5
# properties: 5
# uniquely: 5
# speca3: 5
# shrink: 5
# d/sd: 5
# e|y0: 5
# generization: 5
# university: 5
# daniel: 4
# establish: 4
# infinitesimal: 4
# more: 4
# squares: 4
# author: 4
# supported: 4
# tt16: 4
# extending: 4
# characteristics: 4
# hr15: 4
# defn: 4
# embeddable: 4
# refinements: 4
# 12.5: 4
# pro-affine-immersion: 4
# satisfying: 4
# moreover: 4
# ray70: 4
# deligne–mumford: 4
# necessarily: 4
# here: 4
# z/2z: 4
# quasi-coherent: 4
# situation: 4
# equivalent: 4
# perfect: 4
# functor: 4
# back: 4
# however: 4
# precisely: 4
# reduced: 4
# torus: 4
# 1.12: 4
# complex: 4
# θ-stratum: 4
# restricting: 4
# theory: 4
# well: 4
# reduction: 4
# holds: 4
# lift: 4
# 2-isomorphisms: 4
# factors: 4
# exact: 4
# part: 4
# qcoh: 4
# obstruction: 4
# griz: 4
# griw: 4
# presented: 4
# sheaf: 4
# find: 4
# class: 4
# cartesian: 4
# each: 4
# trivial: 4
# descent: 4
# ww♦♦♦: 4
# specaj: 4
# regular: 4
# 16.12: 4
# spectrum: 4
# gant: 4
# fiber: 4
# τ≤nx: 4
# lur04: 4
# threefold: 4
# raynaud: 4
# 2019: 4
# tokyo: 4
# grothendieck: 4
# amer: 4
# 2017: 4
# k-theory: 4
# email: 4
# address: 4
# abstract: 3
# their: 3
# introduction: 3
# fibered: 3
# groupoids: 3
# milnor: 3
# partially: 3
# research: 3
# temkin: 3
# tyomkin: 3
# discussion: 3
# multiplicative: 3
# means: 3
# important: 3
# refinement: 3
# speca/g: 3
# pro-étale: 3
# transition: 3
# admit: 3
# appendix: 3
# restriction: 3
# pull-back: 3
# 1.11: 3
# complexes: 3
# com-: 3
# ℵ0-crisp: 3
# complement: 3
# immediately: 3
# make: 3
# come: 3
# geometry: 3
# relative: 3
# hl14: 3
# free: 3
# ahlh18: 3
# contained: 3
# special: 3
# need: 3
# defining: 3
# nilpotent: 3
# isomor-: 3
# instead: 3
# ϕ|zn: 3
# η|zn: 3
# applying: 3
# hr19: 3
# preliminary: 3
# homomorphism: 3
# nakayama: 3
# element: 3
# assumption: 3
# induction: 3
# necessary: 3
# whose: 3
# vanishes: 3
# 2.11: 3
# canonical: 3
# artin–rees: 3
# coker: 3
# hypothesis: 3
# 2.12: 3
# claims: 3
# cofiltered: 3
# above: 3
# iso-: 3
# corresponds: 3
# lifts: 3
# belongs: 3
# diagonals: 3
# everything: 3
# faces: 3
# reduce: 3
# union: 3
# specc2: 3
# smooth-locally: 3
# xuvj: 3
# adequate: 3
# ×bgln: 3
# conormal: 3
# field: 3
# composition: 3
# quasi-finite: 3
# faithfully: 3
# hr18: 3
# pick: 3
# zero-locus: 3
# non-existence: 3
# proper: 3
# curves: 3
# divisor: 3
# intersects: 3
# univ: 3
# press: 3
# michel: 3
# schémas: 3
# inst: 3
# springer-verlag: 3
# applications: 2
# variant: 2
# positively: 2
# generalization: 2
# art69: 2
# algebraizations: 2
# proven: 2
# cj02: 2
# used: 2
# 2020: 2
# grant: 2
# foundation: 2
# third: 2
# council: 2
# natural: 2
# //❴❴❴: 2
# elk73: 2
# non-affine: 2
# generalize: 2
# neigh-: 2
# §2.2: 2
# order: 2
# versions: 2
# number: 2
# different: 2
# nag62: 2
# form: 2
# reader: 2
# merely: 2
# below: 2
# non-closed: 2
# inclusions: 2
# g|w0: 2
# speca0/g0: 2
# initial: 2
# diagrams: 2
# closely: 2
# greco: 2
# strano: 2
# gs81: 2
# mil71: 2
# hk19: 2
# consequence: 2
# strong: 2
# always: 2
# finding: 2
# tt90: 2
# nee96: 2
# were: 2
# shown: 2
# characterization: 2
# subset: 2
# tor-amplitude: 2
# analogue: 2
# 1.13: 2
# denotes: 2
# filt: 2
# regard: 2
# arise: 2
# projective: 2
# establishes: 2
# functors: 2
# 2-isomorphism: 2
# family: 2
# equivalence: 2
# speca: 2
# 13.7: 2
# vas69: 2
# ring: 2
# tive: 2
# r/i-modules: 2
# n/in+1: 2
# ins/in+1s: 2
# s/ids: 2
# props: 2
# griy: 2
# grix: 2
# clearly: 2
# under: 2
# -modules: 2
# objects: 2
# into: 2
# square-zero: 2
# dotted: 2
# arrow: 2
# ou×sx: 2
# ŝ×sx: 2
# increasing: 2
# restricts: 2
# constructed: 2
# os′×sx: 2
# tensoring: 2
# integer: 2
# system: 2
# fitting: 2
# therefore: 2
# simultaneously: 2
# argument: 2
# choose: 2
# ψn+1: 2
# formal: 2
# fn−1: 2
# ols06: 2
# ext2: 2
# lw0/x0: 2
# knu71: 2
# egai: 2
# yields: 2
# global: 2
# zariski-localization: 2
# ☎☎☎☎~�: 2
# cocartesian: 2
# fppf: 2
# topology: 2
# sight: 2
# cube: 2
# immediate: 2
# just: 2
# observation: 2
# |x1|: 2
# |x2|: 2
# |x3|: 2
# tensor: 2
# a3-algebra: 2
# ⑧⑧⑧⑧⑧: 2
# pullback: 2
# specc0: 2
# easily: 2
# arranged: 2
# choice: 2
# full: 2
# take: 2
# verified: 2
# groupoid: 2
# being: 2
# reducing: 2
# ∗ow0: 2
# 16.14: 2
# oy0/i: 2
# ����: 2
# egaiv: 2
# localized: 2
# immer-: 2
# sions: 2
# pre-: 2
# smooth/étale/syntomic: 2
# tot04: 2
# gro17: 2
# 15.3: 2
# →֒xλ: 2
# before: 2
# algebraically: 2
# specκ: 2
# passing: 2
# subgroup: 2
# proves: 2
# connected: 2
# normal: 2
# cartier: 2
# gaff: 2
# anti-affine: 2
# bri09: 2
# gln/g: 2
# ranges: 2
# eventually: 2
# pro-affine-open: 2
# divisors: 2
# says: 2
# product: 2
# acts: 2
# rank: 2
# 1≤d≤e: 2
# stiefel: 2
# frame: 2
# ehkv01: 2
# secd: 2
# simplicial: 2
# represented: 2
# t-exact: 2
# lies: 2
# ext1: 2
# defines: 2
# truncation: 2
# clπn: 2
# nilcomplete: 2
# 5.3.7: 2
# lw0/y0: 2
# monomorphisms: 2
# non-projective: 2
# har77: 2
# references: 2
# 2018: 2
# 1969: 2
# éléments: 2
# géométrie: 2
# algébrique: 2
# hautes: 2
# études: 2
# publ: 2
# descente: 2
# trans: 2
# reine: 2
# angew: 2
# negative: 2
# amnon: 2
# neeman: 2
# representations: 2
# 2015: 2
# berlin: 2
# 1971: 2
# lecture: 2
# notes: 2
# 2004: 2
# institute: 2
# technology: 2
# princeton: 2
# anneaux: 2
# 2016: 2
# project: 2
# //stacks.math.columbia.edu/: 2
# boston: 2
# michael: 2
# ilya: 2
# department: 2
# étale: 2
# par-: 1
# ticular: 1
# coun-: 1
# terparts: 1
# answers: 1
# temkin–tyomkin: 1
# technical: 1
# paper: 1
# algebraiza-: 1
# tion: 1
# approxi-: 1
# mation: 1
# approach: 1
# gener-: 1
# alizes: 1
# return: 1
# shortly: 1
# date: 1
# 2022: 1
# subject: 1
# classification: 1
# 14b12: 1
# 14d23: 1
# 13b12: 1
# words: 1
# phrases: 1
# dms-1801976: 1
# dms-2100088: 1
# grants: 1
# dms-1945478: 1
# career: 1
# dms-1601967: 1
# simons: 1
# collaboration: 1
# alfred: 1
# sloan: 1
# australian: 1
# dp210103397: 1
# fourth: 1
# swedish: 1
# 2015-05554: 1
# göran: 1
# gustafsson: 1
# sciences: 1
# medicine: 1
# //arxiv.org/abs/2205.08623v1: 1
# 04d1: 1
# answer: 1
# qstn: 1
# borhoods: 1
# formulate: 1
# mixed-characteristic: 1
# often: 1
# impose: 1
# remind: 1
# another: 1
# //stacks.math.columbia.edu/tag/04d1: 1
# fibers: 1
# intersections: 1
# context: 1
# §16–17: 1
# charts: 1
# 17.4: 1
# range: 1
# object: 1
# called: 1
# require: 1
# related: 1
# settle: 1
# conjectures: 1
# conj: 1
# analogous: 1
# semi-localization: 1
# alge-: 1
# braic: 1
# certain: 1
# simple: 1
# 1.10: 1
# 13.1: 1
# cover: 1
# stabi-: 1
# lizers: 1
# sume: 1
# v/glm: 1
# non-separated: 1
# line: 1
# whereas: 1
# unbounded: 1
# cohomology: 1
# vexing: 1
# years: 1
# been: 1
# whether: 1
# homox: 1
# homx: 1
# preserves: 1
# small: 1
# coproducts: 1
# definitive: 1
# pioneering: 1
# work: 1
# thorough: 1
# subtleties: 1
# refer: 1
# interested: 1
# progress: 1
# made: 1
# 14.1: 1
# pact: 1
# provided: 1
# eliminate: 1
# discrepancy: 1
# supp: 1
# cotangent: 1
# funda-: 1
# mental: 1
# underlying: 1
# a1/gm: 1
# mapping: 1
# 1.1.2: 1
# 2.1.1: 1
# stratifications: 1
# kind: 1
# invariant: 1
# torsion: 1
# 6.11: 1
# proving: 1
# semistable: 1
# 1.14: 1
# a/i+: 1
# elements: 1
# degree: 1
# state: 1
# terminology: 1
# consists: 1
# equivalently: 1
# −1iy: 1
# e.g.: 1
# solid: 1
# arrows: 1
# 2-morphisms: 1
# whole: 1
# a.19: 1
# 12.14: 1
# cellent: 1
# most: 1
# statement: 1
# valid: 1
# arbitrary: 1
# difference: 1
# obtains: 1
# discussing: 1
# background: 1
# material: 1
# explain: 1
# conclude: 1
# introduced: 1
# studied: 1
# func-: 1
# abelian: 1
# colimit: 1
# quasi-excellent: 1
# latter: 1
# simply: 1
# speca/i: 1
# i-adically: 1
# fundamen-: 1
# i-adic: 1
# provide: 1
# criteria: 1
# check: 1
# surjec-: 1
# a-modules: 1
# a-module: 1
# identify: 1
# treat: 1
# endomorphism: 1
# module: 1
# tells: 1
# suppose: 1
# momorphism: 1
# gris: 1
# induces: 1
# generatedr/i-modules: 1
# in/in+1: 1
# sequences: 1
# id/id+1: 1
# r/id+1: 1
# ϕd+1: 1
# r/id: 1
# ids/id+1s: 1
# s/id+1s: 1
# a.10: 1
# oy0-: 1
# reduces: 1
# seen: 1
# oy0-modules: 1
# conversely: 1
# hold: 1
# said: 1
# generally: 1
# affine-pointed: 1
# theoretic: 1
# |z0|: 1
# hypotheses: 1
# -module: 1
# filtration: 1
# associated: 1
# pushforwards: 1
# extensions: 1
# verify: 1
# ext1t: 1
# classes: 1
# pulling: 1
# ot×sx: 1
# satisfy: 1
# a.15: 1
# respect: 1
# lying: 1
# s′×s: 1
# ⊗os′×sx: 1
# β′|s′: 1
# otn×sx: 1
# -algebras: 1
# plexes: 1
# fined: 1
# a.16: 1
# a.17: 1
# weak: 1
# presen-: 1
# tation: 1
# together: 1
# s-schemes: 1
# meeting: 1
# meaning: 1
# approximate: 1
# guarantees: 1
# produces: 1
# the-: 1
# orem: 1
# would: 1
# like: 1
# wn+1: 1
# ξ|wn+1: 1
# possible: 1
# define: 1
# followed: 1
# isomz: 1
# sections: 1
# suffi-: 1
# ciently: 1
# pull-backs: 1
# steps: 1
# wn−1: 1
# xn−1: 1
# struction: 1
# ωw0/x0: 1
# 0.7.2.8: 1
# alongw0: 1
# thatwi: 1
# applies: 1
# 1when: 1
# η|wn: 1
# preimage: 1
# agrees: 1
# withw0: 1
# finishes: 1
# exposition: 1
# follow: 1
# useful: 1
# begin: 1
# ∗ox2: 1
# ∗ox0: 1
# ∗ox1: 1
# ←−x0: 1
# −→x1: 1
# geomet-: 1
# lemmas—the: 1
# mild: 1
# ✆✆✆✆~�: 1
# prior: 1
# affine—whence: 1
# left: 1
# bottom: 1
# imme-: 1
# diately: 1
# algebras: 1
# a0-isomorphisms: 1
# patible: 1
# questions: 1
# about: 1
# similarly: 1
# |u1|: 1
# |u2|: 1
# |u3|: 1
# surjectivity: 1
# already: 1
# remarked: 1
# smoothness: 1
# fibral: 1
# argue: 1
# a3-module: 1
# a3-sub-algebras: 1
# filtered: 1
# direct: 1
# limits: 1
# commute: 1
# products: 1
# homomorphisms: 1
# looking: 1
# cokernel: 1
# aj-algebra: 1
# know: 1
# kernel: 1
# a3-flat: 1
# aj-module: 1
# p3-module: 1
# critical: 1
# almost: 1
# identical: 1
# 2-cocartesian: 1
# ==x3: 1
# smooth-local: 1
# compatibly: 1
# pulls: 1
# specc1: 1
# c2×c0c1: 1
# specc3: 1
# speccj: 1
# 2-morphism: 1
# checked: 1
# coincide: 1
# between: 1
# repeat: 1
# 2-subcategory: 1
# clear: 1
# ∐l∈λx: 1
# cd−1: 1
# inductive: 1
# xuv3: 1
# universal: 1
# rise: 1
# v∈λx: 1
# ∐w∈λx: 1
# inherits: 1
# deligne–: 1
# mumford: 1
# inherited: 1
# generalizations: 1
# similar: 1
# lines: 1
# 12.1: 1
# —smooth/étale: 1
# effective: 1
# solution: 1
# handled: 1
# —syntomic: 1
# x0×bgln: 1
# ox0-algebra: 1
# setting: 1
# syme0: 1
# i0/i: 1
# //❴❴❴❴: 1
# homoy: 1
# borhood: 1
# requested: 1
# noy0: 1
# basis: 1
# 11.3.8: 1
# images: 1
# |w0|: 1
# |x0|: 1
# provides: 1
# non-: 1
# cases: 1
# changes: 1
# once: 1
# sentation: 1
# fol-: 1
# lows: 1
# totaro–gross: 1
# having: 1
# descend: 1
# sented: 1
# sta-: 1
# bilizers: 1
# gen-: 1
# eration: 1
# implications: 1
# implication: 1
# view: 1
# coarse: 1
# certainly: 1
# taking: 1
# additional: 1
# fppf-locally: 1
# fx|x: 1
# fun-: 1
# damental: 1
# additionally: 1
# 13.4: 1
# strictly: 1
# ∐mi=1w: 1
# ∐fxi: 1
# −−−→: 1
# components: 1
# tori: 1
# those: 1
# include: 1
# lack: 1
# reference: 1
# tags: 1
# 01uf: 1
# 069n: 1
# irreducible: 1
# 0b7r: 1
# even: 1
# g/g0: 1
# done: 1
# 047n: 1
# ogant: 1
# //stacks.math.columbia.edu/tag/01uf: 1
# //stacks.math.columbia.edu/tag/069n: 1
# //stacks.math.columbia.edu/tag/0b7r: 1
# //stacks.math.columbia.edu/tag/047n: 1
# set-theoretic: 1
# 3.1.4: 1
# 3.2.5: 1
# topological: 1
# embedding: 1
# addition: 1
# opens: 1
# introduce: 1
# pro-affine: 1
# -open: 1
# represents: 1
# ∩αvα: 1
# automatically: 1
# q-factorial: 1
# possibly: 1
# infinite: 1
# complements: 1
# unions: 1
# extra: 1
# needed: 1
# one-point: 1
# assumptions: 1
# conclusions: 1
# except: 1
# pro-affine-: 1
# changing: 1
# ∩λxλ: 1
# ∩λ≥α: 1
# descends: 1
# ∩λ≥αwλ: 1
# arguing: 1
# generality: 1
# applied: 1
# respectively: 1
# likewise: 1
# specaβ/gβ: 1
# 16.11: 1
# fx|gx: 1
# ∐x∈|x: 1
# ∐xfx: 1
# nis-: 1
# nevich: 1
# monomorphic: 1
# splitting: 1
# must: 1
# many: 1
# u/gln: 1
# g|gx: 1
# symmetric: 1
# permuting: 1
# maximum: 1
# manifold: 1
# gldn/: 1
# ′/glnd: 1
# 2.13: 1
# p∗p∗e: 1
# split: 1
# considering: 1
# manifolds: 1
# again: 1
# v/gln: 1
# freely: 1
# henselizationwh: 1
# specohw: 1
# sincewh: 1
# conclusion: 1
# 16.4: 1
# ∞-groupoids: 1
# opposite: 1
# ∞-category: 1
# disjoint: 1
# speca/gln: 1
# effectivity: 1
# thickenings: 1
# τ≤mxn: 1
# equivalences: 1
# uniqueness: 1
# 5.4.6: 1
# determined: 1
# n-truncated: 1
# τ≤na: 1
# fn+1: 1
# xn+1: 1
# f∗0lbglr: 1
# πn+1: 1
# oxn+1: 1
# pushforward: 1
# identi-: 1
# fiesqcoh: 1
# ifrγ: 1
# local-: 1
# ized: 1
# very: 1
# →xcl: 1
# deform: 1
# lfcl: 1
# τ≤nw: 1
# w0×x0: 1
# proceed: 1
# becomes: 1
# obstructions: 1
# vanish: 1
# previously: 1
# denoted: 1
# corresponding: 1
# homotopy: 1
# hurewicz: 1
# f⊗oy0: 1
# e∨|y0: 1
# ✟✟✟✟��: 1
# lw0/z0: 1
# ∨|y0: 1
# contrast: 1
# counter-example: 1
# mentioned: 1
# 3.1.2: 1
# consisting: 1
# andw: 1
# thenw×xw: 1
# equals: 1
# semi-: 1
# localization: 1
# ronaka: 1
# gluing: 1
# blow-ups: 1
# factorial: 1
# numerically: 1
# properly: 1
# intersecting: 1
# satisfied: 1
# equal: 1
# without: 1
# suitable: 1
# endow: 1
# hironaka: 1
# action: 1
# interchanges: 1
# pulls-back: 1
# 0b8a: 1
# 3.1.5: 1
# contradicts: 1
# jochen: 1
# heinloth: 1
# arxiv:1812.01128: 1
# preprint: 1
# arxiv:1912.06162: 1
# luna: 1
# slice: 1
# 675–738: 1
# analysis: 1
# papers: 1
# honor: 1
# kodaira: 1
# 21–71: 1
# brion: 1
# 2009: 1
# 934–952: 1
# brian: 1
# conrad: 1
# jong: 1
# deformations: 1
# 2002: 1
# 489–515: 1
# langage: 1
# 1960: 1
# étude: 1
# locale: 1
# morphismes: 1
# 1964–67: 1
# edidin: 1
# brendan: 1
# hassett: 1
# andrew: 1
# kresch: 1
# angelo: 1
# vistoli: 1
# brauer: 1
# 2001: 1
# 761–777: 1
# renée: 1
# elkik: 1
# solutions: 1
# équations: 1
# coefficients: 1
# dans: 1
# anneau: 1
# hensélien: 1
# école: 1
# norm: 1
# 1973: 1
# 553–603: 1
# 1974: 1
# conducteur: 1
# pincement: 1
# bull: 1
# france: 1
# 2003: 1
# 553–585: 1
# philipp: 1
# gross: 1
# generators: 1
# algebr: 1
# geom: 1
# 501–522: 1
# silvio: 1
# rosario: 1
# quasicoherent: 1
# hensel: 1
# 1981: 1
# 445–465: 1
# openness: 1
# versality: 1
# 137–182: 1
# robin: 1
# hartshorne: 1
# york: 1
# 1977: 1
# graduate: 1
# texts: 1
# marc: 1
# hoyois: 1
# amalendu: 1
# krishna: 1
# vanishing: 1
# 439–472: 1
# instability: 1
# 2014: 1
# arxiv:1411.0627: 1
# jussieu: 1
# 1087–1111: 1
# indiana: 1
# 1903–1923: 1
# compos: 1
# 2318–2367: 1
# addendum: 1
# dévissage: 1
# 2011: 1
# 194–223: 1
# 398–412: 1
# algebraicity: 1
# hom-stacks: 1
# 1633–1675: 1
# donald: 1
# knutson: 1
# math-: 1
# ematics: 1
# jacob: 1
# lurie: 1
# proquest: 1
# arbor: 1
# thesis: 1
# ph.d.: 1
# –massachusetts: 1
# john: 1
# n.j.: 1
# annals: 1
# studies: 1
# masayoshi: 1
# nagata: 1
# reducibility: 1
# rational: 1
# matric: 1
# kyoto: 1
# 1961/62: 1
# 87–99: 1
# //stacks.math.columbia.edu/tag/0b8a: 1
# //arxiv.org/abs/1812.01128: 1
# //arxiv.org/abs/1912.06162: 1
# //arxiv.org/abs/1411.0627: 1
# bousfield: 1
# techniques: 1
# brown: 1
# representability: 1
# 1996: 1
# 205–236: 1
# martin: 1
# olsson: 1
# deformation: 1
# 2006: 1
# 25–62: 1
# critère: 1
# effectivité: 1
# séminaire: 1
# algèbre: 1
# commuta-: 1
# dirigé: 1
# pierre: 1
# samuel: 1
# 1967–1968: 1
# épimorphismes: 1
# secrétariat: 1
# mathématique: 1
# paris: 1
# 1968: 1
# locaux: 1
# henséliens: 1
# 1970: 1
# 105–147: 1
# absolute: 1
# draft: 1
# available: 1
# request: 1
# authors: 1
# burt: 1
# totaro: 1
# 1–22: 1
# thomason: 1
# thomas: 1
# trobaugh: 1
# higher: 1
# festschrift: 1
# progr: 1
# math.: 1
# birkhäuser: 1
# 1990: 1
# 247–435: 1
# 960–983: 1
# prüfer: 1
# 1283–1318: 1
# wolmer: 1
# vasconcelos: 1
# 505–512: 1
# washington: 1
# 354350: 1
# seattle: 1
# 98195-4350: 1
# uw.edu: 1
# malott: 1
# dept: 1
# cornell: 1
# ithaca: 1
# 14853: 1
# daniel.hl: 1
# cornell.edu: 1
# school: 1
# statistics: 1
# melbourne: 1
# parkville: 1
# 3010: 1
# australia: 1
# jack.hall: 1
# unimelb.edu.au: 1
# royal: 1
# se-100: 1
# stock-: 1
# holm: 1
# sweden: 1
# dary: 1
# math.kth.se: 1
# theta-stratum: 1

# %% [markdown]
# We can see that the top words by frequency include words like 'that' and 'then', which we know are not going to be keywords. We can addreess this by pairing words with an appropriate corpas. For instance the words 'theorem', 'algebriac' and 'affine' are important. We can safely remove words like 'that' which are pronouns, adverbs, determiners etc.
#
# We do this by using a dictionary of corporas that pair words with appropriate types. We can then choose to ignore these types:

# %%
import nltk

"""
We want to remove words that correspond to certain tags for instance:

WDT	wh-determiner (that, what)
WP	wh- pronoun (who)
WRB	wh- adverb (how)
EX	existential there
IN	preposition/subordinating conjunction
RB	adverb (occasionally, swiftly)
RBR	adverb, comparative (greater)
RBS	adverb, superlative (biggest)
"""

removing = [
    "WDT"
    , "WP"
    , "WRB"
    , "EX"
    , "IN"
    , "RB"
    , "RBR"
]

for word in word_counts.keys():
    if len(word) > 3:
        if nltk.pos_tag([word])[0][1] not in removing:
            print("{}: {}".format(word, word_counts[word]))
# Out:
# affine: 143
# theorem: 125
# algebraic: 110
# closed: 103
# fundamental: 96
# morphism: 89
# stacks: 79
# smooth: 69
# étale: 64
# such: 63
# finite: 62
# this: 58
# immersion: 57
# local: 45
# stack: 42
# assume: 41
# structure: 40
# isomorphism: 39
# proof: 39
# resp: 38
# neighborhood: 37
# open: 36
# quasi-compact: 34
# pairs: 33
# derived: 33
# have: 32
# follows: 32
# case: 32
# type: 31
# ahr19: 31
# scheme: 30
# every: 30
# lemma: 28
# algebraization: 27
# quasi-separated: 27
# space: 27
# artin: 26
# following: 26
# presentation: 26
# point: 26
# satisfies: 26
# syntomic: 25
# exists: 25
# prop: 24
# hall: 23
# rydh: 23
# complete: 23
# substack: 23
# neighborhoods: 22
# prove: 22
# flat: 22
# diagonal: 22
# pair: 22
# application: 20
# result: 19
# induced: 19
# schemes: 19
# property: 19
# surjective: 19
# morphisms: 19
# existence: 18
# diagram: 18
# moduli: 18
# geometric: 18
# section: 18
# noetherian: 18
# alper: 17
# group: 17
# pushout: 17
# spec: 17
# image: 17
# math: 17
# halpern-leistner: 16
# spaces: 16
# nisnevich: 16
# apply: 16
# pushouts: 15
# some: 15
# separated: 15
# square: 15
# compatible: 14
# stabilizers: 14
# replacing: 14
# replace: 14
# step: 14
# ahr20: 13
# points: 13
# note: 13
# large: 13
# proposition: 13
# sequence: 13
# hence: 13
# results: 12
# http: 12
# characteristic: 12
# stabilizer: 12
# representable: 12
# arrange: 12
# category: 11
# definition: 11
# bgln: 11
# reductive: 11
# resolution: 11
# zariskification: 11
# ryd15: 11
# bundle: 11
# ferrand: 10
# david: 10
# these: 10
# versal: 10
# conditions: 10
# positive: 10
# good: 10
# 2-commutative: 10
# limit: 10
# base: 10
# claim: 10
# jack: 9
# subscheme: 9
# will: 9
# consider: 9
# nice: 9
# phism: 9
# quasi-: 9
# both: 9
# maps: 9
# compact: 9
# denote: 9
# obtain: 9
# specz: 9
# give: 8
# exist: 8
# general: 8
# version: 8
# mathematics: 8
# either: 8
# admits: 8
# does: 8
# covering: 8
# modules: 8
# generated: 8
# classical: 8
# immersions: 8
# remains: 8
# main: 7
# using: 7
# groups: 7
# example: 7
# residual: 7
# gerbe: 7
# fer03: 7
# unique: 7
# dqcoh: 7
# established: 7
# quasi-smooth: 7
# defined: 7
# duality: 7
# cohomological: 7
# dimension: 7
# criterion: 7
# containing: 7
# specb: 7
# monomorphism: 7
# factorization: 7
# henselizations: 6
# question: 6
# rings: 6
# ideal: 6
# henselization: 6
# extension: 6
# condition: 6
# mor-: 6
# zero: 6
# inverse: 6
# remark: 6
# quasi-affine: 6
# generation: 6
# hr17: 6
# identity: 6
# 1-stack: 6
# adic: 6
# particular: 6
# tannaka: 6
# graded: 6
# surjection: 6
# approximation: 6
# construction: 6
# change: 6
# write: 6
# isomorphisms: 6
# vector: 6
# hal17: 6
# 2-cartesian: 6
# show: 6
# tt17: 6
# pro-open: 6
# ray68: 6
# bglr: 6
# algebra: 6
# jarod: 5
# subschemes: 5
# substacks: 5
# theorems: 5
# henselian: 5
# excellent: 5
# second: 5
# recall: 5
# i.e.: 5
# non-noetherian: 5
# pro-affine-immersions: 5
# 2-category: 5
# inclusion: 5
# generalizes: 5
# implies: 5
# quotient: 5
# sheaves: 5
# hnr19: 5
# component: 5
# categories: 5
# given: 5
# commutative: 5
# same: 5
# gives: 5
# coherent: 5
# completion: 5
# 2.10: 5
# lifting: 5
# contains: 5
# factor: 5
# suffices: 5
# isomorphic: 5
# standard: 5
# methods: 5
# extend: 5
# resulting: 5
# ryd16: 5
# intersection: 5
# extends: 5
# properties: 5
# speca3: 5
# shrink: 5
# d/sd: 5
# e|y0: 5
# generization: 5
# university: 5
# daniel: 4
# establish: 4
# infinitesimal: 4
# squares: 4
# author: 4
# supported: 4
# tt16: 4
# extending: 4
# characteristics: 4
# hr15: 4
# defn: 4
# embeddable: 4
# refinements: 4
# 12.5: 4
# pro-affine-immersion: 4
# satisfying: 4
# moreover: 4
# ray70: 4
# deligne–mumford: 4
# z/2z: 4
# quasi-coherent: 4
# situation: 4
# equivalent: 4
# perfect: 4
# functor: 4
# reduced: 4
# torus: 4
# 1.12: 4
# complex: 4
# θ-stratum: 4
# restricting: 4
# theory: 4
# reduction: 4
# holds: 4
# lift: 4
# 2-isomorphisms: 4
# factors: 4
# exact: 4
# part: 4
# qcoh: 4
# obstruction: 4
# griz: 4
# griw: 4
# presented: 4
# sheaf: 4
# find: 4
# class: 4
# cartesian: 4
# each: 4
# trivial: 4
# descent: 4
# ww♦♦♦: 4
# specaj: 4
# regular: 4
# 16.12: 4
# spectrum: 4
# gant: 4
# fiber: 4
# τ≤nx: 4
# lur04: 4
# threefold: 4
# raynaud: 4
# 2019: 4
# tokyo: 4
# grothendieck: 4
# amer: 4
# 2017: 4
# k-theory: 4
# email: 4
# address: 4
# abstract: 3
# their: 3
# introduction: 3
# fibered: 3
# groupoids: 3
# milnor: 3
# research: 3
# temkin: 3
# tyomkin: 3
# discussion: 3
# multiplicative: 3
# means: 3
# important: 3
# refinement: 3
# speca/g: 3
# pro-étale: 3
# transition: 3
# admit: 3
# appendix: 3
# restriction: 3
# pull-back: 3
# 1.11: 3
# complexes: 3
# com-: 3
# ℵ0-crisp: 3
# complement: 3
# make: 3
# come: 3
# geometry: 3
# relative: 3
# hl14: 3
# free: 3
# ahlh18: 3
# contained: 3
# special: 3
# need: 3
# defining: 3
# nilpotent: 3
# isomor-: 3
# ϕ|zn: 3
# η|zn: 3
# applying: 3
# hr19: 3
# preliminary: 3
# homomorphism: 3
# nakayama: 3
# element: 3
# assumption: 3
# induction: 3
# necessary: 3
# whose: 3
# vanishes: 3
# 2.11: 3
# canonical: 3
# artin–rees: 3
# coker: 3
# hypothesis: 3
# 2.12: 3
# claims: 3
# cofiltered: 3
# iso-: 3
# corresponds: 3
# lifts: 3
# belongs: 3
# diagonals: 3
# everything: 3
# faces: 3
# reduce: 3
# union: 3
# specc2: 3
# xuvj: 3
# adequate: 3
# ×bgln: 3
# conormal: 3
# field: 3
# composition: 3
# quasi-finite: 3
# hr18: 3
# pick: 3
# zero-locus: 3
# non-existence: 3
# proper: 3
# curves: 3
# divisor: 3
# intersects: 3
# univ: 3
# press: 3
# michel: 3
# schémas: 3
# inst: 3
# springer-verlag: 3
# applications: 2
# variant: 2
# generalization: 2
# art69: 2
# algebraizations: 2
# proven: 2
# cj02: 2
# used: 2
# 2020: 2
# grant: 2
# foundation: 2
# third: 2
# council: 2
# natural: 2
# //❴❴❴: 2
# elk73: 2
# non-affine: 2
# generalize: 2
# neigh-: 2
# §2.2: 2
# order: 2
# versions: 2
# number: 2
# different: 2
# nag62: 2
# form: 2
# reader: 2
# non-closed: 2
# inclusions: 2
# g|w0: 2
# speca0/g0: 2
# initial: 2
# diagrams: 2
# greco: 2
# strano: 2
# gs81: 2
# mil71: 2
# hk19: 2
# consequence: 2
# strong: 2
# finding: 2
# tt90: 2
# nee96: 2
# were: 2
# shown: 2
# characterization: 2
# subset: 2
# tor-amplitude: 2
# analogue: 2
# 1.13: 2
# denotes: 2
# filt: 2
# regard: 2
# arise: 2
# projective: 2
# establishes: 2
# functors: 2
# 2-isomorphism: 2
# family: 2
# equivalence: 2
# speca: 2
# 13.7: 2
# vas69: 2
# ring: 2
# tive: 2
# r/i-modules: 2
# n/in+1: 2
# ins/in+1s: 2
# s/ids: 2
# props: 2
# griy: 2
# grix: 2
# -modules: 2
# objects: 2
# square-zero: 2
# dotted: 2
# arrow: 2
# ou×sx: 2
# ŝ×sx: 2
# increasing: 2
# restricts: 2
# constructed: 2
# os′×sx: 2
# tensoring: 2
# integer: 2
# system: 2
# fitting: 2
# argument: 2
# choose: 2
# ψn+1: 2
# formal: 2
# fn−1: 2
# ols06: 2
# ext2: 2
# lw0/x0: 2
# knu71: 2
# egai: 2
# yields: 2
# global: 2
# zariski-localization: 2
# ☎☎☎☎~�: 2
# cocartesian: 2
# fppf: 2
# topology: 2
# sight: 2
# cube: 2
# immediate: 2
# observation: 2
# |x1|: 2
# |x2|: 2
# |x3|: 2
# tensor: 2
# a3-algebra: 2
# ⑧⑧⑧⑧⑧: 2
# pullback: 2
# specc0: 2
# arranged: 2
# choice: 2
# full: 2
# take: 2
# verified: 2
# groupoid: 2
# being: 2
# reducing: 2
# ∗ow0: 2
# 16.14: 2
# oy0/i: 2
# ����: 2
# egaiv: 2
# localized: 2
# immer-: 2
# sions: 2
# pre-: 2
# smooth/étale/syntomic: 2
# tot04: 2
# gro17: 2
# 15.3: 2
# →֒xλ: 2
# specκ: 2
# passing: 2
# subgroup: 2
# proves: 2
# connected: 2
# normal: 2
# cartier: 2
# gaff: 2
# anti-affine: 2
# bri09: 2
# gln/g: 2
# ranges: 2
# pro-affine-open: 2
# divisors: 2
# says: 2
# product: 2
# acts: 2
# rank: 2
# 1≤d≤e: 2
# stiefel: 2
# frame: 2
# ehkv01: 2
# secd: 2
# simplicial: 2
# represented: 2
# t-exact: 2
# lies: 2
# ext1: 2
# defines: 2
# truncation: 2
# clπn: 2
# nilcomplete: 2
# 5.3.7: 2
# lw0/y0: 2
# monomorphisms: 2
# non-projective: 2
# har77: 2
# references: 2
# 2018: 2
# 1969: 2
# éléments: 2
# géométrie: 2
# algébrique: 2
# hautes: 2
# études: 2
# publ: 2
# descente: 2
# trans: 2
# reine: 2
# angew: 2
# negative: 2
# amnon: 2
# neeman: 2
# representations: 2
# 2015: 2
# berlin: 2
# 1971: 2
# lecture: 2
# notes: 2
# 2004: 2
# institute: 2
# technology: 2
# princeton: 2
# anneaux: 2
# 2016: 2
# project: 2
# //stacks.math.columbia.edu/: 2
# boston: 2
# michael: 2
# ilya: 2
# department: 2
# étale: 2
# par-: 1
# ticular: 1
# coun-: 1
# terparts: 1
# answers: 1
# temkin–tyomkin: 1
# technical: 1
# paper: 1
# algebraiza-: 1
# tion: 1
# approxi-: 1
# mation: 1
# approach: 1
# gener-: 1
# alizes: 1
# return: 1
# date: 1
# 2022: 1
# subject: 1
# classification: 1
# 14b12: 1
# 14d23: 1
# 13b12: 1
# words: 1
# phrases: 1
# dms-1801976: 1
# dms-2100088: 1
# grants: 1
# dms-1945478: 1
# career: 1
# dms-1601967: 1
# simons: 1
# collaboration: 1
# alfred: 1
# sloan: 1
# australian: 1
# dp210103397: 1
# fourth: 1
# swedish: 1
# 2015-05554: 1
# göran: 1
# gustafsson: 1
# sciences: 1
# medicine: 1
# //arxiv.org/abs/2205.08623v1: 1
# 04d1: 1
# answer: 1
# qstn: 1
# borhoods: 1
# formulate: 1
# mixed-characteristic: 1
# impose: 1
# remind: 1
# another: 1
# //stacks.math.columbia.edu/tag/04d1: 1
# fibers: 1
# intersections: 1
# context: 1
# §16–17: 1
# charts: 1
# 17.4: 1
# range: 1
# object: 1
# called: 1
# require: 1
# related: 1
# settle: 1
# conjectures: 1
# conj: 1
# analogous: 1
# semi-localization: 1
# alge-: 1
# braic: 1
# certain: 1
# simple: 1
# 1.10: 1
# 13.1: 1
# cover: 1
# stabi-: 1
# lizers: 1
# sume: 1
# v/glm: 1
# non-separated: 1
# line: 1
# whereas: 1
# unbounded: 1
# cohomology: 1
# vexing: 1
# years: 1
# been: 1
# homox: 1
# homx: 1
# preserves: 1
# small: 1
# coproducts: 1
# definitive: 1
# pioneering: 1
# work: 1
# thorough: 1
# subtleties: 1
# refer: 1
# interested: 1
# progress: 1
# made: 1
# 14.1: 1
# pact: 1
# provided: 1
# eliminate: 1
# discrepancy: 1
# supp: 1
# cotangent: 1
# funda-: 1
# mental: 1
# underlying: 1
# a1/gm: 1
# mapping: 1
# 1.1.2: 1
# 2.1.1: 1
# stratifications: 1
# kind: 1
# invariant: 1
# torsion: 1
# 6.11: 1
# proving: 1
# semistable: 1
# 1.14: 1
# a/i+: 1
# elements: 1
# degree: 1
# state: 1
# terminology: 1
# consists: 1
# −1iy: 1
# e.g.: 1
# solid: 1
# arrows: 1
# 2-morphisms: 1
# whole: 1
# a.19: 1
# 12.14: 1
# cellent: 1
# most: 1
# statement: 1
# valid: 1
# arbitrary: 1
# difference: 1
# obtains: 1
# discussing: 1
# background: 1
# material: 1
# explain: 1
# conclude: 1
# introduced: 1
# studied: 1
# func-: 1
# abelian: 1
# colimit: 1
# quasi-excellent: 1
# latter: 1
# speca/i: 1
# fundamen-: 1
# i-adic: 1
# provide: 1
# criteria: 1
# check: 1
# surjec-: 1
# a-modules: 1
# a-module: 1
# identify: 1
# treat: 1
# endomorphism: 1
# module: 1
# tells: 1
# suppose: 1
# momorphism: 1
# gris: 1
# induces: 1
# generatedr/i-modules: 1
# in/in+1: 1
# sequences: 1
# id/id+1: 1
# r/id+1: 1
# ϕd+1: 1
# r/id: 1
# ids/id+1s: 1
# s/id+1s: 1
# a.10: 1
# oy0-: 1
# reduces: 1
# seen: 1
# oy0-modules: 1
# hold: 1
# said: 1
# affine-pointed: 1
# theoretic: 1
# |z0|: 1
# hypotheses: 1
# -module: 1
# filtration: 1
# associated: 1
# pushforwards: 1
# extensions: 1
# verify: 1
# ext1t: 1
# classes: 1
# pulling: 1
# ot×sx: 1
# satisfy: 1
# a.15: 1
# respect: 1
# lying: 1
# s′×s: 1
# ⊗os′×sx: 1
# β′|s′: 1
# otn×sx: 1
# -algebras: 1
# plexes: 1
# fined: 1
# a.16: 1
# a.17: 1
# weak: 1
# presen-: 1
# tation: 1
# s-schemes: 1
# meeting: 1
# meaning: 1
# approximate: 1
# guarantees: 1
# produces: 1
# the-: 1
# orem: 1
# would: 1
# wn+1: 1
# ξ|wn+1: 1
# possible: 1
# define: 1
# followed: 1
# isomz: 1
# sections: 1
# suffi-: 1
# pull-backs: 1
# steps: 1
# wn−1: 1
# xn−1: 1
# struction: 1
# ωw0/x0: 1
# 0.7.2.8: 1
# alongw0: 1
# thatwi: 1
# applies: 1
# 1when: 1
# η|wn: 1
# preimage: 1
# agrees: 1
# withw0: 1
# finishes: 1
# exposition: 1
# follow: 1
# useful: 1
# begin: 1
# ∗ox2: 1
# ∗ox0: 1
# ∗ox1: 1
# ←−x0: 1
# −→x1: 1
# geomet-: 1
# lemmas—the: 1
# mild: 1
# ✆✆✆✆~�: 1
# affine—whence: 1
# left: 1
# bottom: 1
# imme-: 1
# algebras: 1
# a0-isomorphisms: 1
# patible: 1
# questions: 1
# |u1|: 1
# |u2|: 1
# |u3|: 1
# surjectivity: 1
# remarked: 1
# smoothness: 1
# fibral: 1
# argue: 1
# a3-module: 1
# a3-sub-algebras: 1
# filtered: 1
# direct: 1
# limits: 1
# commute: 1
# products: 1
# homomorphisms: 1
# looking: 1
# cokernel: 1
# aj-algebra: 1
# know: 1
# kernel: 1
# a3-flat: 1
# aj-module: 1
# p3-module: 1
# critical: 1
# identical: 1
# 2-cocartesian: 1
# ==x3: 1
# smooth-local: 1
# pulls: 1
# specc1: 1
# c2×c0c1: 1
# specc3: 1
# speccj: 1
# 2-morphism: 1
# checked: 1
# coincide: 1
# repeat: 1
# 2-subcategory: 1
# clear: 1
# ∐l∈λx: 1
# cd−1: 1
# inductive: 1
# xuv3: 1
# universal: 1
# rise: 1
# v∈λx: 1
# ∐w∈λx: 1
# inherits: 1
# deligne–: 1
# mumford: 1
# inherited: 1
# generalizations: 1
# similar: 1
# lines: 1
# 12.1: 1
# —smooth/étale: 1
# effective: 1
# solution: 1
# handled: 1
# —syntomic: 1
# x0×bgln: 1
# ox0-algebra: 1
# setting: 1
# syme0: 1
# i0/i: 1
# //❴❴❴❴: 1
# homoy: 1
# borhood: 1
# requested: 1
# noy0: 1
# basis: 1
# 11.3.8: 1
# images: 1
# |w0|: 1
# |x0|: 1
# provides: 1
# non-: 1
# cases: 1
# changes: 1
# sentation: 1
# fol-: 1
# lows: 1
# totaro–gross: 1
# having: 1
# descend: 1
# sented: 1
# sta-: 1
# bilizers: 1
# gen-: 1
# eration: 1
# implications: 1
# implication: 1
# view: 1
# coarse: 1
# taking: 1
# additional: 1
# fx|x: 1
# fun-: 1
# damental: 1
# 13.4: 1
# ∐mi=1w: 1
# ∐fxi: 1
# −−−→: 1
# components: 1
# tori: 1
# those: 1
# include: 1
# lack: 1
# reference: 1
# tags: 1
# 01uf: 1
# 069n: 1
# irreducible: 1
# 0b7r: 1
# g/g0: 1
# done: 1
# 047n: 1
# ogant: 1
# //stacks.math.columbia.edu/tag/01uf: 1
# //stacks.math.columbia.edu/tag/069n: 1
# //stacks.math.columbia.edu/tag/0b7r: 1
# //stacks.math.columbia.edu/tag/047n: 1
# set-theoretic: 1
# 3.1.4: 1
# 3.2.5: 1
# topological: 1
# embedding: 1
# addition: 1
# opens: 1
# introduce: 1
# pro-affine: 1
# -open: 1
# represents: 1
# ∩αvα: 1
# q-factorial: 1
# infinite: 1
# complements: 1
# unions: 1
# extra: 1
# needed: 1
# one-point: 1
# assumptions: 1
# conclusions: 1
# pro-affine-: 1
# changing: 1
# ∩λxλ: 1
# ∩λ≥α: 1
# descends: 1
# ∩λ≥αwλ: 1
# arguing: 1
# generality: 1
# applied: 1
# specaβ/gβ: 1
# 16.11: 1
# fx|gx: 1
# ∐x∈|x: 1
# ∐xfx: 1
# nis-: 1
# nevich: 1
# monomorphic: 1
# splitting: 1
# must: 1
# many: 1
# u/gln: 1
# g|gx: 1
# symmetric: 1
# permuting: 1
# maximum: 1
# manifold: 1
# gldn/: 1
# ′/glnd: 1
# 2.13: 1
# p∗p∗e: 1
# split: 1
# considering: 1
# manifolds: 1
# v/gln: 1
# henselizationwh: 1
# specohw: 1
# sincewh: 1
# conclusion: 1
# 16.4: 1
# ∞-groupoids: 1
# opposite: 1
# ∞-category: 1
# disjoint: 1
# speca/gln: 1
# effectivity: 1
# thickenings: 1
# τ≤mxn: 1
# equivalences: 1
# uniqueness: 1
# 5.4.6: 1
# determined: 1
# n-truncated: 1
# τ≤na: 1
# fn+1: 1
# xn+1: 1
# f∗0lbglr: 1
# πn+1: 1
# oxn+1: 1
# pushforward: 1
# identi-: 1
# fiesqcoh: 1
# ifrγ: 1
# local-: 1
# ized: 1
# →xcl: 1
# deform: 1
# lfcl: 1
# τ≤nw: 1
# w0×x0: 1
# proceed: 1
# becomes: 1
# obstructions: 1
# vanish: 1
# denoted: 1
# corresponding: 1
# homotopy: 1
# hurewicz: 1
# f⊗oy0: 1
# e∨|y0: 1
# ✟✟✟✟��: 1
# lw0/z0: 1
# ∨|y0: 1
# contrast: 1
# counter-example: 1
# mentioned: 1
# 3.1.2: 1
# consisting: 1
# andw: 1
# thenw×xw: 1
# equals: 1
# semi-: 1
# localization: 1
# ronaka: 1
# gluing: 1
# blow-ups: 1
# factorial: 1
# intersecting: 1
# satisfied: 1
# equal: 1
# suitable: 1
# endow: 1
# hironaka: 1
# action: 1
# interchanges: 1
# pulls-back: 1
# 0b8a: 1
# 3.1.5: 1
# contradicts: 1
# jochen: 1
# heinloth: 1
# arxiv:1812.01128: 1
# preprint: 1
# arxiv:1912.06162: 1
# luna: 1
# slice: 1
# 675–738: 1
# analysis: 1
# papers: 1
# honor: 1
# kodaira: 1
# 21–71: 1
# brion: 1
# 2009: 1
# 934–952: 1
# brian: 1
# conrad: 1
# jong: 1
# deformations: 1
# 2002: 1
# 489–515: 1
# langage: 1
# 1960: 1
# étude: 1
# locale: 1
# morphismes: 1
# 1964–67: 1
# edidin: 1
# brendan: 1
# hassett: 1
# andrew: 1
# kresch: 1
# angelo: 1
# vistoli: 1
# brauer: 1
# 2001: 1
# 761–777: 1
# renée: 1
# elkik: 1
# solutions: 1
# équations: 1
# coefficients: 1
# dans: 1
# anneau: 1
# hensélien: 1
# école: 1
# norm: 1
# 1973: 1
# 553–603: 1
# 1974: 1
# conducteur: 1
# pincement: 1
# bull: 1
# france: 1
# 2003: 1
# 553–585: 1
# philipp: 1
# gross: 1
# generators: 1
# algebr: 1
# geom: 1
# 501–522: 1
# silvio: 1
# rosario: 1
# quasicoherent: 1
# hensel: 1
# 1981: 1
# 445–465: 1
# openness: 1
# versality: 1
# 137–182: 1
# robin: 1
# hartshorne: 1
# york: 1
# 1977: 1
# graduate: 1
# texts: 1
# marc: 1
# hoyois: 1
# amalendu: 1
# krishna: 1
# vanishing: 1
# 439–472: 1
# instability: 1
# 2014: 1
# arxiv:1411.0627: 1
# jussieu: 1
# 1087–1111: 1
# indiana: 1
# 1903–1923: 1
# compos: 1
# 2318–2367: 1
# addendum: 1
# dévissage: 1
# 2011: 1
# 194–223: 1
# 398–412: 1
# algebraicity: 1
# hom-stacks: 1
# 1633–1675: 1
# donald: 1
# knutson: 1
# math-: 1
# ematics: 1
# jacob: 1
# lurie: 1
# proquest: 1
# arbor: 1
# thesis: 1
# ph.d.: 1
# –massachusetts: 1
# john: 1
# n.j.: 1
# annals: 1
# studies: 1
# masayoshi: 1
# nagata: 1
# reducibility: 1
# rational: 1
# matric: 1
# kyoto: 1
# 1961/62: 1
# 87–99: 1
# //stacks.math.columbia.edu/tag/0b8a: 1
# //arxiv.org/abs/1812.01128: 1
# //arxiv.org/abs/1912.06162: 1
# //arxiv.org/abs/1411.0627: 1
# bousfield: 1
# techniques: 1
# brown: 1
# representability: 1
# 1996: 1
# 205–236: 1
# martin: 1
# olsson: 1
# deformation: 1
# 2006: 1
# 25–62: 1
# critère: 1
# effectivité: 1
# séminaire: 1
# algèbre: 1
# commuta-: 1
# dirigé: 1
# pierre: 1
# samuel: 1
# 1967–1968: 1
# épimorphismes: 1
# secrétariat: 1
# mathématique: 1
# paris: 1
# 1968: 1
# locaux: 1
# henséliens: 1
# 1970: 1
# 105–147: 1
# absolute: 1
# draft: 1
# available: 1
# request: 1
# authors: 1
# burt: 1
# totaro: 1
# 1–22: 1
# thomason: 1
# thomas: 1
# trobaugh: 1
# higher: 1
# festschrift: 1
# progr: 1
# math.: 1
# birkhäuser: 1
# 1990: 1
# 247–435: 1
# 960–983: 1
# prüfer: 1
# 1283–1318: 1
# wolmer: 1
# vasconcelos: 1
# 505–512: 1
# washington: 1
# 354350: 1
# seattle: 1
# 98195-4350: 1
# uw.edu: 1
# malott: 1
# dept: 1
# cornell: 1
# ithaca: 1
# 14853: 1
# daniel.hl: 1
# cornell.edu: 1
# school: 1
# statistics: 1
# melbourne: 1
# parkville: 1
# 3010: 1
# australia: 1
# jack.hall: 1
# unimelb.edu.au: 1
# royal: 1
# se-100: 1
# stock-: 1
# holm: 1
# sweden: 1
# dary: 1
# math.kth.se: 1
# theta-stratum: 1
